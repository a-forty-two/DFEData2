# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/DFEData2/blob/main/02_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://github.com/a-forty-two/DFEData2/archive/refs/heads/main.zip
# !unzip main.zip -d potato
# Out:
# --2021-10-13 15:16:01--  https://github.com/a-forty-two/DFEData2/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/a-forty-two/DFEData2/zip/refs/heads/main [following]
# --2021-10-13 15:16:01--  https://codeload.github.com/a-forty-two/DFEData2/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [ <=>                ] 405.22K  --.-KB/s    in 0.03s
#
# 2021-10-13 15:16:01 (15.6 MB/s) - ‘main.zip’ saved [414943]
#
# Archive:  main.zip
# 673ca0bb6aa41c760fb05d04796a9e4ab5bc87d9
#    creating: potato/DFEData2-main/
# ...

# %%
# Only for Google Colab, refer to next block for everything else

from google.colab.patches import cv2_imshow
# pandas-> dataframes
# opencv -> Computer Vision algorithms, and heavylifiting (matrices simplied)
import cv2
i1 = cv2.imread('/content/hoooo.jpg')
cv2_imshow(i1)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F8C177F5190>

# %%
# ONLY for VS Code
# pandas-> dataframes
# opencv -> Computer Vision algorithms, and heavylifiting (matrices simplied)
# !pip install opencv-python
import cv2
i1 = cv2.imread('/content/hoooo.jpg')
cv2.imshow(i1)

# %%
i1[0][0] # First Pixel of my image!
# Out:
# array([60, 55, 34], dtype=uint8)

# %%
i1.shape
# Out:
# (168, 300, 3)

# %%
i2 = cv2.cvtColor(i1)
# Out:
# [[ 60  55  34]
#  [ 48  43  22]
#  [ 44  40  16]
#  [ 53  49  25]
#  [ 58  54  29]
#  [ 51  47  22]
#  [ 47  44  16]
#  [ 51  49  19]
#  [ 47  45  15]
#  [ 50  48  17]
#  [ 68  67  33]
#  [ 79  78  44]
#  [ 95  95  59]
#  [ 51  51  15]
#  [ 32  33   0]
#  [ 40  41   2]
#  [ 47  45   5]
#  [ 61  59  19]
#  [ 64  61  23]
#  [ 64  61  23]
#  [ 51  46  13]
#  [ 55  50  17]
#  [ 73  67  38]
#  [ 61  55  26]
#  [ 60  53  28]
#  [ 58  51  26]
#  [ 55  46  26]
#  [ 52  43  23]
#  [ 51  41  24]
#  [ 52  42  25]
#  [ 54  43  29]
#  [ 56  46  28]
#  [ 48  41  16]
#  [ 65  59  30]
#  [ 87  81  52]
#  [ 61  56  25]
#  [ 80  77  46]
#  [ 55  53  18]
#  [ 78  78  42]
#  [ 95  96  56]
#  [104 105  65]
#  [ 43  46   1]
#  [116 121  76]
#  [ 87  93  44]
#  [ 82  91  41]
#  [112 121  70]
#  [104 114  61]
#  [ 53  59  12]
#  [ 38  33   0]
#  [ 36  27   0]
#  [ 42  33   6]
#  [ 50  41  14]
#  [ 48  38  14]
#  [ 51  41  17]
#  [ 53  42  22]
#  [ 40  29   9]
#  [ 46  34  16]
#  [ 44  32  14]
# ...
