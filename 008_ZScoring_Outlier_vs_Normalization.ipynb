# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/DFEData2/blob/main/008_ZScoring_Outlier_vs_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type 1
# Z-Scoring-> normalization
# data, xtrain,ytrain,xtest,ytest
mu = xtrain.mean, sigma = xtrain.std 
trainx_norm = (xtrain-mu)/sigma
testx_norm = (xtest-mu)/sigma

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('Screen Shot 2021-11-11 at 8.28.36 PM.png')
img = cv2.resize(img, (800,450))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F5951D26A50>

# %%
# Type 2
# Z-Scoring => Outlier detection
# data, xtrain,ytrain,xtest,ytest
mu = data.mean, sigma = data.std
trainx_norm = (xtrain-mu)/sigma
testx_norm = (xtest-mu)/sigma
# removed +3/-3 from trainx_norm and testx_norm

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('Screen Shot 2021-11-11 at 8.38.11 PM.png')
img = cv2.resize(img, (800,450))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F5951CDA390>

# %%
#type 3
# Never use- no gain or objective at all
# data, xtrain,ytrain,xtest,ytest
mu1 = xtrain.mean, sigma1 = xtrain.std
mu2 = xtest.mean, sigma2 = xtest.std
trainx_norm = (xtrain-mu1)/sigma1
testx_norm = (xtest-mu2)/sigma2
