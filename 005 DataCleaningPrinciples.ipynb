# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = '353b9ff5-223a-4dc4-853e-825bc329d30c'
resource_group = 'rotato'
workspace_name = 'coolcool'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='bca')
data = dataset.to_pandas_dataframe()
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Tabular Dataset
# Data to be clean
#   1. No missing or duplicate values
#.  2. Cardinality -> discrete or continuous 
#.  3. Outliers removal -> z-score 
#.  4. Reduce dimensions -> correlation, PCA, LDA
#.  5. Order -> tens, thousands, millions? -> reduce to all the same-> Normalization (Z-score, MinMax, tanh...)
#.  6. Data Validation-> data confirms the business rules

# %%
# let's assume
# point-> 6 is done for us

# %%
# 1. No missing or duplicate values
def check_missing_or_null(data):
    mynulls= data.isna().sum()
    allnulls = mynulls[mynulls > 0]  # this gives me all the null values
    data = data.drop_duplicates()
    return data, len(allnulls)

# %%
# !pip install pandas --upgrade
import pandas as pd
print(pd.__version__)
data= pd.DataFrame(data)
print(data.value_counts())
#dir(data)
# Out:
# Requirement already up-to-date: pandas in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.1.5)
# ...
# 1.1.5
# id         diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst
# ...

# %%
def remove_useless_columns(data):
    # from EDA-> inference-> remove ID
    # Always perform EDA before this
    data = data.set_index('id')
    return data

# %%
# EDA step-> because my ID column's correlation is tending to 0, we choose to eliminate it 
crs = data.corr()
crs
# we realize-> ID needs to be removed from my feature list!
# Out:
#                                id  radius_mean  texture_mean  perimeter_mean  \
# id                       1.000000     0.074626      0.099770        0.073159
# radius_mean              0.074626     1.000000      0.323782        0.997855
# texture_mean             0.099770     0.323782      1.000000        0.329533
# perimeter_mean           0.073159     0.997855      0.329533        1.000000
# area_mean                0.096893     0.987357      0.321086        0.986507
# smoothness_mean         -0.012968     0.170581     -0.023389        0.207278
# compactness_mean         0.000096     0.506124      0.236702        0.556936
# concavity_mean           0.050080     0.676764      0.302418        0.716136
# concave points_mean      0.044158     0.822529      0.293464        0.850977
# symmetry_mean           -0.022114     0.147741      0.071401        0.183027
# fractal_dimension_mean  -0.052511    -0.311631     -0.076437       -0.261477
# ...

# %%
data[data.radius_mean < 15]
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 3    84348301         M        11.42         20.38           77.58      386.1
# 5      843786         M        12.45         15.70           82.57      477.1
# 7    84458202         M        13.71         20.83           90.20      577.9
# 8      844981         M        13.00         21.82           87.50      519.8
# 9    84501001         M        12.46         24.04           83.97      475.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B        14.59         22.68           96.39      657.1
# 559    925291         B        11.51         23.93           74.52      403.5
# 560    925292         B        14.05         27.15           91.38      600.4
# 561    925311         B        11.20         29.37           70.67      386.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
data.isna().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# 2: Cardinality Check 
for column_name in data.columns:
    print(column_name + " - " + str(data[column_name].value_counts().count()))
    
# Objective-> identify discrete and continuous numbers

# total-> 569 inside
# 2 values in Diag, 456 values in radius_mean
# diag-> Disc
# radius -> continuous
# Out:
# id - 569
# diagnosis - 2
# radius_mean - 456
# texture_mean - 479
# perimeter_mean - 522
# area_mean - 539
# smoothness_mean - 474
# compactness_mean - 537
# concavity_mean - 537
# concave points_mean - 542
# symmetry_mean - 432
# fractal_dimension_mean - 499
# radius_se - 540
# texture_se - 519
# perimeter_se - 533
# area_se - 528
# smoothness_se - 547
# compactness_se - 541
# concavity_se - 533
# concave points_se - 507
# symmetry_se - 498
# fractal_dimension_se - 545
# radius_worst - 457
# texture_worst - 511
# perimeter_worst - 514
# area_worst - 544
# smoothness_worst - 411
# compactness_worst - 529
# concavity_worst - 539
# concave points_worst - 492
# symmetry_worst - 500
# fractal_dimension_worst - 535
